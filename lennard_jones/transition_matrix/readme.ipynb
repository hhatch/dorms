# %% [markdown]
# # Transition-Matrix Monte Carlo

# %%
import pandas as pd
df = pd.read_csv('../../dorms-data/lennard_jones/transition_matrix/ln_prob_energ.csv')
print(df)
df.plot()
# Out:
#      macro   ln_prob        energy
# 0        0 -274.7280 -8.284730e-15
# 1        1 -270.0560 -6.057400e-04
# 2        2 -266.0690 -3.033800e-02
# 3        3 -262.4800 -8.996390e-02
# 4        4 -259.1720 -1.795610e-01
# ..     ...       ...           ...
# 366    366  -26.7744 -1.709570e+03
# 367    367  -27.7478 -1.718020e+03
# 368    368  -28.7330 -1.726400e+03
# 369    369  -29.7371 -1.734630e+03
# 370    370  -30.8093 -1.743220e+03
#
# [371 rows x 3 columns]
# <AxesSubplot:>
